# %%
URL="https://www.inmobusqueda.com.ar/"
URL ="https://www.youtube.com/"
URL="https://www.tiktok.com/"
URL="https://www.labrujula.com.ar/"
URL="https://www.mercadolibre.com.ar/"

# %% [markdown]
# ## URL="https://www.inmobusqueda.com.ar/"

# %%
from IPython.display import Image, display
display(Image(filename='C:\Técnico-Universitario-Data-Science\Pocesamiento-Natural-Del-Lenguaje(NPL)\Web-Scraping/inmobiliaria.png'))

# %% [markdown]
# ## URL ="https://www.youtube.com/"

# %%
from IPython.display import Image, display
display(Image(filename='C:\Técnico-Universitario-Data-Science\Pocesamiento-Natural-Del-Lenguaje(NPL)\Web-Scraping/Youtube.png'))

# %% [markdown]
# ## URL="https://www.tiktok.com/"

# %%
from IPython.display import Image, display
display(Image(filename='C:\Técnico-Universitario-Data-Science\Pocesamiento-Natural-Del-Lenguaje(NPL)\Web-Scraping/Tiktok.png'))

# %% [markdown]
# ## URL="https://www.labrujula.com.ar/"

# %%
from IPython.display import Image, display
display(Image(filename='C:\Técnico-Universitario-Data-Science\Pocesamiento-Natural-Del-Lenguaje(NPL)\Web-Scraping/Labrujula.png'))

# %% [markdown]
# ## URL="https://www.mercadolibre.com.ar/"

# %%
from IPython.display import Image, display
display(Image(filename='C:\Técnico-Universitario-Data-Science\Pocesamiento-Natural-Del-Lenguaje(NPL)\Web-Scraping/Mercadolibre.png'))
